# %%
import pandas as pd

# %%
s=pd.Series([67,33,12,56,78,21], index=range(100,106))

# %%
s
# Out:
# 100    67
# 101    33
# 102    12
# 103    56
# 104    78
# 105    21
# dtype: int64

# %%
roll=pd.Series(range(1,6))
name=pd.Series(['Akash','Ajay','Asha','Amruta','Anil'])
marks=pd.Series([56.78,65.23,76.34,61.23,71.34])

# %% [markdown]
# # DATAFRAME

# %%
name
# Out:
# 0     Akash
# 1      Ajay
# 2      Asha
# 3    Amruta
# 4      Anil
# dtype: object

# %%
df=pd.DataFrame({
    'Roll No.' :roll,
    'Name' :name,
    'Marks' :marks
})
df

# %%
import os
os.getcwd()

# %% [markdown]
#                                                 Stuctured Data Analysis

# %%
cols=['A','B','C','D','H']
df=pd.read_csv('student.csv', names=cols)
df

# %%
import pandas as pd
df=pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
df
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# 7    4.4  2.9  1.4  0.2     Iris-setosa
# 8    4.9  3.1  1.5  0.1     Iris-setosa
# 9    5.4  3.7  1.5  0.2     Iris-setosa
# 10   4.8  3.4  1.6  0.2     Iris-setosa
# 11   4.8  3.0  1.4  0.1     Iris-setosa
# 12   4.3  3.0  1.1  0.1     Iris-setosa
# 13   5.8  4.0  1.2  0.2     Iris-setosa
# 14   5.7  4.4  1.5  0.4     Iris-setosa
# 15   5.4  3.9  1.3  0.4     Iris-setosa
# 16   5.1  3.5  1.4  0.3     Iris-setosa
# 17   5.7  3.8  1.7  0.3     Iris-setosa
# 18   5.1  3.8  1.5  0.3     Iris-setosa
# 19   5.4  3.4  1.7  0.2     Iris-setosa
# 20   5.1  3.7  1.5  0.4     Iris-setosa
# 21   4.6  3.6  1.0  0.2     Iris-setosa
# ...

# %%
cols=['A','B','C','D','H']
df=pd.read_csv('student3.tsv', sep='\t')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
df.mean()
# Out:
# roll                                       (5.5+0j)
# name     (1.140307257684e-312+1.140307257744e-312j)
# class     (1.14030725773e-312+1.140307257754e-312j)
# marks                                   (64.499+0j)
# age                                       (20.5+0j)
# dtype: complex128

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
df.max()
# Out:
# roll         10
# name     ayesha
# class        TE
# marks     78.66
# age          23
# dtype: object

# %%
df.min()
# Out:
# roll           1
# name     ajinkya
# class         BE
# marks      49.55
# age           19
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
# roll     10 non-null int64
# name     10 non-null object
# class    10 non-null object
# marks    10 non-null float64
# age      10 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 480.0+ bytes

# %%
df.describe()
# Out:
#            roll      marks        age
# count  10.00000  10.000000  10.000000
# mean    5.50000  64.499000  20.500000
# std     3.02765   9.207179   1.269296
# min     1.00000  49.550000  19.000000
# 25%     3.25000  57.520000  20.000000
# 50%     5.50000  64.310000  20.000000
# 75%     7.75000  69.327500  21.000000
# max    10.00000  78.660000  23.000000

# %%
df.count()
# Out:
# roll     10
# name     10
# class    10
# marks    10
# age      10
# dtype: int64

# %%
df.mode()
# Out:
#    roll     name class  marks   age
# 0     1  ajinkya    BE  49.55  20.0
# 1     2     amar    TE  56.75   NaN
# 2     3     amit   NaN  56.77   NaN
# 3     4    amita   NaN  59.77   NaN
# 4     5     amol   NaN  63.28   NaN
# 5     6   aniket   NaN  65.34   NaN
# 6     7     anil   NaN  68.33   NaN
# 7     8    anmol   NaN  69.66   NaN
# 8     9     asha   NaN  76.88   NaN
# 9    10   ayesha   NaN  78.66   NaN

# %%
x=df.iloc[4:8,1:4]
x
# Out:
#      name class  marks
# 4    asha    TE  63.28
# 5  ayesha    BE  49.55
# 6    amar    BE  65.34
# 7   amita    BE  68.33

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5     ayesha
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','marks']]
# Out:
#       name  marks
# 0     anil  56.77
# 1     amit  59.77
# 2   aniket  76.88
# 3  ajinkya  69.66
# 4     asha  63.28
# 5   ayesha  49.55
# 6     amar  65.34
# 7    amita  68.33
# 8     amol  56.75
# 9    anmol  78.66

# %%
df.drop(['class','age'], axis=1)
# Out:
#    roll     name  marks
# 0     1     anil  56.77
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 5     6   ayesha  49.55
# 6     7     amar  65.34
# 7     8    amita  68.33
# 8     9     amol  56.75
# 9    10    anmol  78.66

# %%
df.sum(axis=1)
# Out:
# 0     79.77
# 1     82.77
# 2     98.88
# 3     93.66
# 4     88.28
# 5     75.55
# 6     91.34
# 7     99.33
# 8     85.75
# 9    109.66
# dtype: float64

# %%
df.sum()
# Out:
# roll                                                    55
# name     anilamitaniketajinkyaashaayeshaamaramitaamolanmol
# class                                 TETEBETETEBEBEBETEBE
# marks                                               644.99
# age                                                    205
# dtype: object

# %%
id(df)
# Out:
# 2308007669944

# %%
import numpy as np
gender=np.array(['M','M','M','M','F','F','M','F','M','M',])
gender
# Out:
# array(['M', 'M', 'M', 'M', 'F', 'F', 'M', 'F', 'M', 'M'], dtype='<U1')

# %%
df['gender']=gender
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      M
# 1     2     amit    TE  59.77   21      M
# 2     3   aniket    BE  76.88   19      M
# 3     4  ajinkya    TE  69.66   20      M
# 4     5     asha    TE  63.28   20      F
# 5     6   ayesha    BE  49.55   20      F
# 6     7     amar    BE  65.34   19      M
# 7     8    amita    BE  68.33   23      F
# 8     9     amol    TE  56.75   20      M
# 9    10    anmol    BE  78.66   21      M

# %%
df['cgpa']=df['marks']/10+1.05
df
# Out:
#    roll     name class  marks  age gender   cgpa
# 0     1     anil    TE  56.77   22      M  6.727
# 1     2     amit    TE  59.77   21      M  7.027
# 2     3   aniket    BE  76.88   19      M  8.738
# 3     4  ajinkya    TE  69.66   20      M  8.016
# 4     5     asha    TE  63.28   20      F  7.378
# 5     6   ayesha    BE  49.55   20      F  6.005
# 6     7     amar    BE  65.34   19      M  7.584
# 7     8    amita    BE  68.33   23      F  7.883
# 8     9     amol    TE  56.75   20      M  6.725
# 9    10    anmol    BE  78.66   21      M  8.916
